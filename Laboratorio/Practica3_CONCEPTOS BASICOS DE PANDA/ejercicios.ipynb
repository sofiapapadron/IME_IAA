# %% [markdown]
# # Ejercicios
#
# Escriba el codigo en la celda correspondiente para resolver el problema planteado.

# %% [markdown]
# ## Fundamentos
#
# En esta parte se trabajara con el dataset ***homelessness***, este es un homelessnessset que contiene estimaciones de personas sin hogar en cada estado de EE. UU. en 2018.
#
# La columna "individual" es el número de personas sin hogar que no forman parte de una familia con niños.
#
# La columna "family_members" es el número de personas sin hogar que forman parte de una familia con niños.
#
# La columna "state_pop" es la población total del estado.

# %% [markdown]
# importar pandas como ***pd***

# %%
import pandas as pd

# %% [markdown]
# Importar el archivo *homelessness.csv*

# %%
homelessness = pd.read_csv('https://raw.githubusercontent.com/sofiapapadron/IME_IAA/main/Laboratorio/Practica3_CONCEPTOS%20BASICOS%20DE%20PANDA/datasets/homelessness.csv?token=GHSAT0AAAAAACWAYALQ43U2KJPHWEAVI5D4ZWQYHPQ')

# %% [markdown]
# Utilice las funciones ***head() y tail()*** para visualizar los datos

# %%
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
homelessness.tail()
# Out:
#     Unnamed: 0              region          state  individuals  \
# 46          46      South Atlantic       Virginia       3928.0
# 47          47             Pacific     Washington      16424.0
# 48          48      South Atlantic  West Virginia       1021.0
# 49          49  East North Central      Wisconsin       2740.0
# 50          50            Mountain        Wyoming        434.0
#
#     family_members  state_pop
# 46          2047.0    8501286
# 47          5880.0    7523869
# 48           222.0    1804291
# 49          2167.0    5807406
# 50           205.0     577601

# %% [markdown]
# Imprima las columnas y el tipo de dato de cada columna utilizando la función ***info()***

# %%
homelessness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     object
#  2   state           51 non-null     object
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.5+ KB

# %% [markdown]
# Imprima las ***columnas*** del homelessnessset

# %%
homelessness.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %% [markdown]
# ### Ordenar y filtrar Datos

# %% [markdown]
# Ordene el dataset *homelessness* por *individuals*, de menor a mayor, guarde el sesultado en una variable llamada *homelessness_ind*.
#
# Imprima los primeros elementos del resultado.

# %%
homelessness_ind = homelessness.sort_values('individuals')
homelessness_ind.head()
# Out:
#     Unnamed: 0              region         state  individuals  family_members  \
# 50          50            Mountain       Wyoming        434.0           205.0
# 34          34  West North Central  North Dakota        467.0            75.0
# 7            7      South Atlantic      Delaware        708.0           374.0
# 39          39         New England  Rhode Island        747.0           354.0
# 45          45         New England       Vermont        780.0           511.0
#
#     state_pop
# 50     577601
# 34     758080
# 7      965479
# 39    1058287
# 45     624358

# %% [markdown]
# Ordene el dataset *homelessness* primero por *region (ascendente)* y luego por *family_members (descendente)*, guarde el sesultado en una variable llamada *homelessness_reg_fam*.
#
# Imprima los primeros elementos del resultado.

# %%
homelessness_reg_fam = homelessness.sort_values(['region', 'family_members'], ascending=[True, False])
homelessness_reg_fam.head()
# Out:
#     Unnamed: 0              region      state  individuals  family_members  \
# 13          13  East North Central   Illinois       6752.0          3891.0
# 35          35  East North Central       Ohio       6929.0          3320.0
# 22          22  East North Central   Michigan       5209.0          3142.0
# 49          49  East North Central  Wisconsin       2740.0          2167.0
# 14          14  East North Central    Indiana       3776.0          1482.0
#
#     state_pop
# 13   12723071
# 35   11676341
# 22    9984072
# 49    5807406
# 14    6695497

# %% [markdown]
# Crea un homelessnessFrame llamado *state_fam* que contenga únicamente la columna *state* y *family_members*.

# %%
state_fam = homelessness[['state', 'family_members']]
state_fam.head()
# Out:
#         state  family_members
# 0     Alabama           864.0
# 1      Alaska           582.0
# 2     Arizona          2606.0
# 3    Arkansas           432.0
# 4  California         20964.0

# %% [markdown]
# De *state_fam* Obtenga todos los renglones donde *family_members* sea mayor o igual a 2000.

# %%
state_fam[state_fam['family_members'] >= 2000]
# Out:
#                    state  family_members
# 2                Arizona          2606.0
# 4             California         20964.0
# 5               Colorado          3250.0
# 8   District of Columbia          3134.0
# 9                Florida          9587.0
# 10               Georgia          2556.0
# 11                Hawaii          2399.0
# 13              Illinois          3891.0
# 20              Maryland          2230.0
# 21         Massachusetts         13257.0
# 22              Michigan          3142.0
# 23             Minnesota          3250.0
# 25              Missouri          2107.0
# 30            New Jersey          3350.0
# 32              New York         52070.0
# 33        North Carolina          2817.0
# 35                  Ohio          3320.0
# 37                Oregon          3337.0
# 38          Pennsylvania          5349.0
# 43                 Texas          6111.0
# 46              Virginia          2047.0
# 47            Washington          5880.0
# 49             Wisconsin          2167.0

# %% [markdown]
# De *state_fam* Obtenga todos los renglones donde  *state* sea New York o Washington

# %%
state_fam[(state_fam['state'] == 'New York') | (state_fam['state'] == 'Washington')]
# Out:
#          state  family_members
# 32    New York         52070.0
# 47  Washington          5880.0

# %% [markdown]
# ### Generar nuevas columnas

# %% [markdown]
# Agrega una nueva columna llamada ***total***, esta columna tendrá la suma de *individuals* y *family_members*.

# %%
homelessness['total'] = homelessness['individuals'] + homelessness['family_members']
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop     total
# 0    4887681    3434.0
# 1     735139    2016.0
# 2    7158024    9865.0
# 3    3009733    2712.0
# 4   39461588  129972.0

# %% [markdown]
# ## Funciones de agregación
#
# En esta sección se trabajará con el dataset de ventas de Walmart.
#
# Este dataset contiene ventas semanales de varias tiendas de los Estados Unidos.

# %% [markdown]
# ### Funciones estadisticas

# %% [markdown]
# Importe el dataset ***sales_subset*** e imprima los primeros datos usando la función *head()*.

# %%
sales_subset = pd.read_csv('https://raw.githubusercontent.com/sofiapapadron/IME_IAA/main/Laboratorio/Practica3_CONCEPTOS%20BASICOS%20DE%20PANDA/datasets/sales_subset.csv?token=GHSAT0AAAAAACWAYALRLRQSLJMWPZ2LC6F4ZWQYJCA')
sales_subset.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %% [markdown]
# Obtenga el promedio y la mediana de la columna *weekly_sales*

# %%
sales_subset['weekly_sales'].mean()
# Out:
# 23843.95014850566

# %%
sales_subset['weekly_sales'].median()
# Out:
# 12049.064999999999

# %% [markdown]
# Imprima la fecha minima de la columna *date*.

# %%
sales_subset['date'].min()
# Out:
# '2010-02-05'

# %% [markdown]
# ### Funciones para variables categoricas

# %% [markdown]
# Se desea saber cuantos tipos de tiendas diferentes existen, elimine todas las tiendas que tengan el mismo **type** y **store** y almacenelo en una variable llamada *store_types*.

# %%
store_types = sales_subset.drop_duplicates(subset=['type', 'store'])
store_types.head()
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 0              0      1    A           1  2010-02-05      24924.50
# 901          901      2    A           1  2010-02-05      35034.06
# 1798        1798      4    A           1  2010-02-05      38724.42
# 2699        2699      6    A           1  2010-02-05      25619.00
# 3593        3593     10    B           1  2010-02-05      40212.84
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0          False       5.727778              0.679451         8.106
# 901        False       4.550000              0.679451         8.324
# 1798       False       6.533333              0.686319         8.623
# 2699       False       4.683333              0.679451         7.259
# 3593       False      12.411111              0.782478         9.765

# %% [markdown]
# Cuente el número de tiendas de cada tipo

# %%
store_types['type'].value_counts()
# Out:
# type
# A    11
# B     1
# Name: count, dtype: int64

# %% [markdown]
# ### Agrupamiento

# %% [markdown]
# Agrupe las ventas por *type* y obtenga la suma y el promedio de la columna *weekly_sales*.

# %%
sales_subset.groupby('type')['weekly_sales'].agg(['sum', 'mean'])
# Out:
#                sum          mean
# type
# A     2.337163e+08  23674.667242
# B     2.317840e+07  25696.678370

# %% [markdown]
# Realice la misma operación pero utilizando tablas pivote.

# %%
sales_subset.pivot_table(values='weekly_sales', index='type', aggfunc=['sum', 'mean'])
# Out:
#                sum          mean
#       weekly_sales  weekly_sales
# type
# A     2.337163e+08  23674.667242
# B     2.317840e+07  25696.678370

# %% [markdown]
# Ahora obtenga el promedio de *weekly_sales* agrupando por *type* e *is_holiday*.

# %%
sales_subset.groupby(['type', 'is_holiday'])['weekly_sales'].mean()
# Out:
# type  is_holiday
# A     False         23768.583523
#       True            590.045250
# B     False         25751.980533
#       True            810.705000
# Name: weekly_sales, dtype: float64

# %% [markdown]
# ## Indexado

# %% [markdown]
# ### Subconjuntos con LOC y ILOC

# %% [markdown]
# En esta parte se trabajará con el dataset *temperatures*, este dataset la temperatura promedio mensual en distintas ciudades del mundo.

# %% [markdown]
# Importe el dataset ***temperatures***

# %%
temperatures = pd.read_csv('https://raw.githubusercontent.com/sofiapapadron/IME_IAA/main/Laboratorio/Practica3_CONCEPTOS%20BASICOS%20DE%20PANDA/datasets/temperatures.csv?token=GHSAT0AAAAAACWAYALRAWOOJ6XZOUI73XC4ZWQYOFQ')
temperatures.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547

# %% [markdown]
# Utilizando la función set_index(), asigne como índice la columna *date*, guarde el resultado en una variable llamada *temp_date*.

# %%
temp_date = temperatures.set_index('date')
temp_date.head()
# Out:
#             Unnamed: 0     city        country  avg_temp_c
# date
# 2000-01-01           0  Abidjan  Côte D'Ivoire      27.293
# 2000-02-01           1  Abidjan  Côte D'Ivoire      27.685
# 2000-03-01           2  Abidjan  Côte D'Ivoire      29.061
# 2000-04-01           3  Abidjan  Côte D'Ivoire      28.162
# 2000-05-01           4  Abidjan  Côte D'Ivoire      27.547

# %% [markdown]
# Utilizando el método loc, obtenga todos los renglones del 2010 (es importante ordenar el indice de fecha antes de usar el método loc).

# %%
temp_date = temp_date.sort_index()
temp_date.loc['2010-01-01':'2010-12-31']
# Out:
#             Unnamed: 0        city    country  avg_temp_c
# date
# 2010-01-01        4905  Faisalabad   Pakistan      11.810
# 2010-01-01       10185   Melbourne  Australia      20.016
# 2010-01-01        3750   Chongqing      China       7.921
# 2010-01-01       13155   São Paulo     Brazil      23.738
# 2010-01-01        5400   Guangzhou      China      14.136
# ...                ...         ...        ...         ...
# 2010-12-01        6896     Jakarta  Indonesia      26.602
# 2010-12-01        5246       Gizeh      Egypt      16.530
# 2010-12-01       11186      Nagpur      India      19.120
# 2010-12-01       14981      Sydney  Australia      19.559
# 2010-12-01       13496    Salvador     Brazil      26.265
#
# [1200 rows x 4 columns]

# %% [markdown]
# ### Ejercicio integrado

# %% [markdown]
# Utilizando el dataset *temperatures*, obtenga una nueva columna llamada *year* a partir de la columna *date*.
#
# Almacene el resultado en una variable llamada *year_temp*

# %%
temperatures['year']=temperatures['date'].str[:4]
year_temp = temperatures
year_temp.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c  year
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293  2000
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685  2000
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061  2000
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162  2000
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547  2000

# %% [markdown]
# Asigne el año, el pais y la ciudad como tablas pivote en la variable year_temp para obtener la temperatura en grados Farenheit, el promedio, el valor minimo y maximo de temperaturas.

# %%
year_temp['avg_temp_f'] = (year_temp['avg_temp_c'] * 9/5) + 32
year_temp.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c  year  \
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293  2000
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685  2000
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061  2000
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162  2000
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547  2000
#
#    avg_temp_f
# 0     81.1274
# 1     81.8330
# 2     84.3098
# 3     82.6916
# 4     81.5846

# %%
year_temp.pivot_table(values='avg_temp_f', index=['year', 'country', 'city'], aggfunc=['mean', 'min', 'max'])
# Out:
#                                           mean        min        max
#                                     avg_temp_f avg_temp_f avg_temp_f
# year country       city
# 2000 Afghanistan   Kabul              60.48080    37.9868    78.9926
#      Angola        Luanda             75.93860    70.0268    79.6928
#      Australia     Melbourne          57.77615    47.3684    71.7710
#                    Sydney             63.62135    58.0172    69.2834
#      Bangladesh    Dhaka              78.62945    65.8922    84.6554
# ...                                        ...        ...        ...
# 2013 United States Chicago            52.85640    31.0838    72.0140
#                    Los Angeles        64.61720    47.8634    77.1620
#                    New York           53.89500    29.5430    76.4996
#      Vietnam       Ho Chi Minh City   83.21900    79.8746    85.4384
#      Zimbabwe      Harare             67.56170    61.3382    72.9266
#
# [1400 rows x 3 columns]
